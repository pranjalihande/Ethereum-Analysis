# %%
import ast
import matplotlib.pyplot as plt

def get_graph(filename, title):

    f = open (filename, 'r')
    h = f.readlines()
    x = ast.literal_eval(h[0])
    date = []
    value = []

    for i in x:
        date.append(i[0])
        value.append(i[1])
    
    plt.figure(figsize=(20, 5), dpi=80)
    plt.bar(date, value)
    plt.title(title)
    plt.xlabel('Date: Year-Month')
    plt.ylabel('Transaction Count')
    plt.xticks(rotation = 90)
    plt.show()

# %%
get_graph("part_B_top_10.txt", 'Number of transactions occurring every month')
